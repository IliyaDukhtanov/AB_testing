# %% [markdown]
# # Семинар 5.
# # Применение математической статистики для проверки гипотез в реальной жизни для популярных метрик
# ## Домашнее задание.

# %% [markdown]
# ### Задание 1.
# Вы провели эксперимент c упрощением формы заказа в магазине Утконос и получили результаты по метрике конверсий в покупку.
# Выберите метод оценки и оцените есть ли стат. значимые различия между конверсиями в двух группах при alpha = 5%. Дайте краткие рекомендации команде.
# Результаты:
# 1) Число юзеров в группах , которые заходили на сайт в период эксперимента: n1 = 15550 и n2 = 15550 .
# 2) Число юзеров в группах , которые совершили хотя бы одну покупку за период эксперимента:  n1 = 164 и n2 = 228
# 3) Конверсии : conv1 =  1.05%  conv2 =  1.47% .

# %% [markdown]
# Для оценки результатов эксперимента yнайдём доверительный интервал:

# %% [markdown]
# Исходные данные:

# %%
n1_total, n2_total = 15500, 15500
n1_conv, n2_conv = 164, 228
#conv1, conv2 = 1.05/100, 1.47/100

# %%
import numpy as np

# %%
# Найдем доли конверсии
conv_1 = n1_conv / n1_total
conv_2 = n2_conv / n2_total
#change = np.round(((conv_2 - conv_1) / conv_1) * 100, 2)  # рассчитываем изменение конверсии
#
SE_1 = (conv_1 * (1 - conv_1) / n1_total) ** 0.5  # стандартная ошибка первой группы
SE_2 = (conv_2 * (1 - conv_2) / n2_total) ** 0.5  # стандартная ошибка второй группы
SE_diff = (SE_1 ** 2 + SE_2 ** 2) ** 0.5          # стандартная ошибка разности
#
#z_score = (conv_2 - conv_1) / SE_diff
#pvalue = scipy.stats.norm.sf(abs(z_score)) * 2

# Дополнительно рассчитаем доверительный интервал
left = np.round((conv_2 - conv_1 - 1.96 * SE_diff) * 100, 3)
right = np.round((conv_2 - conv_1 + 1.96 * SE_diff) * 100, 3)
ci = [f"{left}%", f"{right}%"]
print('Доверительный интервал',ci)
# Out:
# Доверительный интервал ['0.164%', '0.662%']

# %% [markdown]
# **Выводы:
# Доверительный интервал положительный и не проходит через 0, что говорит о различиях между данными первой и второй групп.**
#
# ***Рекомендации:
# Упрощение формы заказа показало наличие существенных статистических различий между контрольной и тестовой группой.
# Эксперимент можно развернуть на всех пользователей магазина.***

# %% [markdown]
# ### Задание 2.
# Сравниваем метрику конверсия в покупку. Размер выборки - 10000 элементов в каждой группе .
# Какой статистический критерий тут лучше всего подойдёт и почему ?

# %% [markdown]
# **Следует использовать Z-тест, т.к. имеем независимые выборки, в которых наблюдения принимают два значения: 0 и 1.
# Распределение в выборках нормальное с большой вероятностью.
# При использование ХИ-теста на большой выборке p-value стремится к нулю с ростом статистики. ХИ-тест не подойдёт для выборки в 10000 элементов.**
#
# https://habr.com/ru/company/mygames/blog/677074/
